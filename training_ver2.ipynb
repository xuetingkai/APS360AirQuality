# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# # Reading the Weather and PM2.5 Data
#
# - using min-max normalization

# %%
from data_preprocessing import load_X_y
import pandas as pd

weather_df, pollutant_df = load_X_y()

# %%
weather_df_normalized = (weather_df-weather_df.min())/(weather_df.max()-weather_df.min())
weather_df_normalized.describe()
# Out:
#        max_dew_point_v  max_relative_humidity_v  max_temperature_v  \
# count      7304.000000              7304.000000        7304.000000
# mean          0.514953                 0.571856           0.524171
# std           0.335249                 0.218783           0.335174
# min           0.000000                 0.000000           0.000000
# 25%           0.179659                 0.412934           0.182859
# 50%           0.495475                 0.597683           0.536310
# 75%           0.863534                 0.743629           0.859094
# max           1.000000                 1.000000           1.000000
#
#        max_wind_speed_v  min_dew_point_v  min_relative_humidity_v  \
# count       7304.000000      7304.000000              7304.000000
# mean           0.571205         0.518990                 0.486371
# std            0.255798         0.326785                 0.261585
# min            0.000000         0.000000                 0.000000
# 25%            0.357715         0.201610                 0.258465
# 50%            0.632265         0.500370                 0.435290
# 75%            0.795591         0.851591                 0.731753
# max            1.000000         1.000000                 1.000000
#
#        min_temperature_v  min_wind_speed_v  precipitation_v       rain_v  \
# count        7304.000000       7304.000000      7304.000000  7304.000000
# mean            0.519177          0.510449         0.491174     0.509921
# std             0.314073          0.271372         0.181621     0.244698
# min             0.000000          0.000000         0.000000     0.000000
# 25%             0.210211          0.271762         0.344340     0.237410
# 50%             0.517430          0.509554         0.504717     0.593525
# 75%             0.828169          0.762208         0.617925     0.701439
# max             1.000000          1.000000         1.000000     1.000000
#
#             snow_v  snow_on_ground_v
# count  7304.000000       7304.000000
# mean      0.247726          0.177910
# std       0.315199          0.278788
# min       0.000000          0.000000
# 25%       0.000000          0.000000
# 50%       0.016667          0.000000
# 75%       0.583333          0.360465
# max       1.000000          1.000000

# %%
pollutant_df.describe()
# Out:
#               P2.5
# count  7304.000000
# mean      7.435753
# std       5.374638
# min       0.000000
# 25%       3.916667
# 50%       6.166667
# 75%       9.333333
# max      58.666667

# %%
pollutant_tensor = torch.tensor(pollutant_df['P2.5'].values)
weather_tensor = torch.tensor(weather_df_normalized[:].values)

print(pollutant_tensor.shape)
print(weather_tensor.shape)
# Out:
# torch.Size([7304])
# torch.Size([7304, 12])

# %%
type(pollutant_tensor)
# Out:
# torch.Tensor

# %% [markdown]
# # Dataset
#
# - We'll train using the first 5000+14 days to train, 1000+14 days to validate, 1000+14 days to test
# - Ensure sequencing is maintained
# - Test data will be the latest data as the model is intended to use historical data to predict future data

# %%
from torch.utils.data import Dataset

# %%
# creating a custom dataset in a sliding window manner
class WeatherPollutantDataset(Dataset):
    def __init__(self, weather: torch.Tensor, pollutant: torch.Tensor, window:int):
        self.weather = weather
        self.pollutant = pollutant
        # assumes the data starts on the same day
        # assumes their length is the same
        assert len(self.weather) == len(self.pollutant)
        self.window = window

    def __getitem__(self, index: int):
        """
        Using weather input on day i,i+1,...,i+window-1 to predict pollutant output on i+window
        """
        weather_input = self.weather[index:index+self.window].permute(1,0)
        pollutant_output = self.pollutant[index+1:index+self.window+1]
        return weather_input, pollutant_output

    def __len__(self):
        return len(self.weather) - self.window

# %%
train_set = WeatherPollutantDataset(weather=weather_tensor[:5014], pollutant=pollutant_tensor[:5014], window=14)
val_set   = WeatherPollutantDataset(weather=weather_tensor[5014:6028], pollutant=pollutant_tensor[5014:6028], window=14)
test_set  = WeatherPollutantDataset(weather=weather_tensor[6028:7042], pollutant=pollutant_tensor[6028:7042], window=14)

# %%
print("Number of training data: %d" % len(train_set))
print("Number of validation data: %d" % len(val_set))
print("Number of testing data: %d" % len(test_set))
# Out:
# Number of training data: 5000
# Number of validation data: 1000
# Number of testing data: 1000

# %%
from torch.utils.data import DataLoader

# %%
test_loader = DataLoader(test_set, batch_size=64)
next(iter(test_loader))[0].shape
# Out:
# torch.Size([64, 12, 14])

# %% [markdown]
# # Model

# %%
class CNNLSTM(nn.Module):
    def __init__(self):
        super().__init__()
        self.name = "CNNLSTM"
        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)
        # self.conv1 = nn.Conv1d(in_channels=12, out_channels=64, kernel_size=3, stride=1, padding=1)
        # self.norm1 = nn.BatchNorm1d(num_features = 64)
        # self.conv2 = nn.Conv1d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1)
        # self.norm2 = nn.BatchNorm1d(num_features = 64)
        # self.conv3 = nn.Conv1d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1)
        # self.norm3 = nn.BatchNorm1d(num_features = 64)

        self.conv1 = nn.Conv1d(in_channels=12, out_channels=20, kernel_size=3, stride=1, padding=1)
        self.norm1 = nn.BatchNorm1d(num_features = 32)
        self.conv2 = nn.Conv1d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.norm2 = nn.BatchNorm1d(num_features = 64)
        self.conv3 = nn.Conv1d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.norm3 = nn.BatchNorm1d(num_features = 128)
        self.conv4 = nn.Conv1d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.norm4 = nn.BatchNorm1d(num_features = 256)

        self.lstm = nn.LSTM(input_size=256*14, hidden_size=100, num_layers=3, batch_first=True)
        # self.lstm = nn.LSTM(input_size=64*14, hidden_size=100, num_layers=3, batch_first=True)
        self.linear1 = nn.Linear(100, 20)
        self.linear2 = nn.Linear(20, 14)

    def forward(self, x):
        x = F.relu(self.norm1(torch.cat((x, self.conv1(x)), dim=1)))
        x = F.relu(self.norm2(torch.cat((x, self.conv2(x)), dim=1)))
        x = F.relu(self.norm3(torch.cat((x, self.conv3(x)), dim=1)))
        x = F.relu(self.norm4(torch.cat((x, self.conv4(x)), dim=1)))

        # x = F.relu(self.norm1(self.conv1(x)))
        # x = F.relu(self.norm2(self.conv2(x)))
        # x = F.relu(self.norm3(self.conv3(x)))
        # x = self.pool(x)
        x = x.view(-1, 256*14)
        # x = x.squeeze(dim=2)
        x, _ = self.lstm(x)
        x = F.relu(self.linear1(x))
        x = self.linear2(x)
        return x

# %%
import matplotlib.pyplot as plt
def evaluate(net, loader, criterion):
    total_loss = 0.0
    total_epoch = 0
    for i, data in enumerate(loader, 0):
        inputs, labels = data
        inputs = inputs.float()
        labels = labels.float()
        if torch.cuda.is_available():
          inputs = inputs.cuda()
          labels = labels.cuda()

        outputs = net(inputs)
        loss = criterion(outputs, labels)
        total_loss += loss.item()
        total_epoch += len(labels)
    loss = float(total_loss) / (i + 1)
    return loss

def my_loss():
    return lambda output, target: nn.MSELoss()(output, target) - 0.1*torch.mean((output - torch.mean(output))**2)

def train_net(net, train_set, val_set, batch_size=64, learning_rate=0.002, num_epochs=30, start_epoch=0):
    torch.manual_seed(1000)

    if torch.cuda.is_available():
       net.cuda()
       
    train_loader = torch.utils.data.DataLoader(train_set, shuffle=False)
    val_loader = torch.utils.data.DataLoader(val_set, shuffle=False)
    criterion = nn.MSELoss()
    # criterion = my_loss()
    optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.8)
    # optimizer = optim.Adam(net.parameters(), lr=learning_rate)

    train_loss = np.zeros(num_epochs)
    val_loss = np.zeros(num_epochs)
    net.train()
    for epoch in range(num_epochs):
        total_train_loss = 0.0
        total_norm_loss = 0.0
        total_var_loss = 0.0
        total_epoch = 0

        for i, data in enumerate(train_loader, 0):
            inputs, labels = data
            inputs = inputs.float()
            labels = labels.float()
            if torch.torch.cuda.is_available():
              inputs = inputs.cuda()
              labels = labels.cuda()
            optimizer.zero_grad()
            outputs = net(inputs).squeeze()
            labels = labels.squeeze()


            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            # Calculate the statistics
            total_train_loss += loss.item()
            # total_epoch += len(labels)
            total_epoch += 1
        train_loss[epoch] = float(total_train_loss) / (i+1)
        # val_loss[epoch] = evaluate(net, val_loader, criterion)
        val_loss[epoch] = evaluate(net, val_loader, nn.MSELoss())

        print(("Epoch {}: Train loss: = {} | Validation loss: {}").format(epoch + 1,train_loss[epoch],val_loss[epoch]))
        # Save the current model (checkpoint) to a file
        torch.save(net.state_dict(), 'ckpt/skip_connections/22112023/no_max_pool/skip_connection_momentum=0.8/22112023_mse_batchsize_%d_learningrate_%d_epoch_%d'%(batch_size, learning_rate, start_epoch + epoch))
    net.eval()
    print('Finished Training')
    # Write the train/test loss/err into CSV file for plotting later
    epochs = np.arange(1, num_epochs + 1)
    plt.title("Train loss")
    plt.plot(epochs, train_loss)
    plt.xlabel("Epoch")
    plt.ylabel("Loss")

    plt.title("Validation loss")
    plt.plot(epochs, val_loss)
    plt.xlabel("Epoch")
    plt.ylabel("Loss")

# %%
net = CNNLSTM()
# state = torch.load("ckpt/skip_connections/22112023/no_max_pool/skip_connection/22112023_mse_batchsize_64_learningrate_0_epoch_59")
# net.load_state_dict(state)

train_net(net, train_set, val_set, batch_size=64, learning_rate=0.002, num_epochs=30, start_epoch=0)
# Out:
# Epoch 1: Train loss: = 21.006376487747207 | Validation loss: 37.171033110618595
# Epoch 2: Train loss: = 19.96296303577088 | Validation loss: 36.353164057254794
# Epoch 3: Train loss: = 19.977052071261994 | Validation loss: 36.366822041749955
# Epoch 4: Train loss: = 19.973259860199875 | Validation loss: 36.90447968029976
# Epoch 5: Train loss: = 20.199356556862405 | Validation loss: 36.82941618025303
# Epoch 6: Train loss: = 20.163905147181826 | Validation loss: 36.279080595731735
# Epoch 7: Train loss: = 20.22930472667292 | Validation loss: 35.824650844812396
# Epoch 8: Train loss: = 20.283657974272966 | Validation loss: 36.046711183667185
# Epoch 9: Train loss: = 20.422940993593635 | Validation loss: 36.444013275384904
# Epoch 10: Train loss: = 20.531108643119037 | Validation loss: 35.54793980097771
# Epoch 11: Train loss: = 21.067661689446865 | Validation loss: 34.57067125344276
# Epoch 12: Train loss: = 21.7364513280794 | Validation loss: 34.1707183368206
# Epoch 13: Train loss: = 21.66802452214956 | Validation loss: 34.17047972083092
# Epoch 14: Train loss: = 21.66797772884518 | Validation loss: 34.17047910642624
# Epoch 15: Train loss: = 21.66797764288932 | Validation loss: 34.17047910642624
# Epoch 16: Train loss: = 21.66797764288932 | Validation loss: 34.17047910642624
# Epoch 17: Train loss: = 21.66797764288932 | Validation loss: 34.17047910642624
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\xueti\OneDrive - National University of Singapore\Courses\Y2S1-SEP\APS360\Project\training_ver2.ipynb Cell 18 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training_ver2.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> net = CNNLSTM()
#       <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training_ver2.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> # state = torch.load("ckpt/skip_connections/22112023/no_max_pool/skip_connection/22112023_mse_batchsize_64_learningrate_0_epoch_59")
#       <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training_ver2.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> # net.load_state_dict(state)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training_ver2.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a> train_net(net, train_set, val_set, batch_size=64, learning_rate=0.002, num_epochs=30, start_epoch=0)
#
# c:\Users\xueti\OneDrive - National University of Singapore\Courses\Y2S1-SEP\APS360\Project\training_ver2.ipynb Cell 18 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training_ver2.ipynb#X23sZmlsZQ%3D%3D?line=50'>51</a>   labels = labels.cuda()
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training_ver2.ipynb#X23sZmlsZQ%3D%3D?line=51'>52</a> optimizer.zero_grad()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training_ver2.ipynb#X23sZmlsZQ%3D%3D?line=52'>53</a> outputs = net(inputs).squeeze()
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training_ver2.ipynb#X23sZmlsZQ%3D%3D?line=53'>54</a> labels = labels.squeeze()
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training_ver2.ipynb#X23sZmlsZQ%3D%3D?line=56'>57</a> loss = criterion(outputs, labels)
#
# File c:\Users\xueti\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\xueti\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# c:\Users\xueti\OneDrive - National University of Singapore\Courses\Y2S1-SEP\APS360\Project\training_ver2.ipynb Cell 18 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training_ver2.ipynb#X23sZmlsZQ%3D%3D?line=26'>27</a> def forward(self, x):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training_ver2.ipynb#X23sZmlsZQ%3D%3D?line=27'>28</a>     x = F.relu(self.norm1(torch.cat((x, self.conv1(x)), dim=1)))
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training_ver2.ipynb#X23sZmlsZQ%3D%3D?line=28'>29</a>     x = F.relu(self.norm2(torch.cat((x, self.conv2(x)), dim=1)))
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training_ver2.ipynb#X23sZmlsZQ%3D%3D?line=29'>30</a>     x = F.relu(self.norm3(torch.cat((x, self.conv3(x)), dim=1)))
#
# File c:\Users\xueti\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\xueti\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\xueti\anaconda3\Lib\site-packages\torch\nn\modules\conv.py:310, in Conv1d.forward(self, input)
#     309 def forward(self, input: Tensor) -> Tensor:
# --> 310     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\xueti\anaconda3\Lib\site-packages\torch\nn\modules\conv.py:306, in Conv1d._conv_forward(self, input, weight, bias)
#     302 if self.padding_mode != 'zeros':
#     303     return F.conv1d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     304                     weight, bias, self.stride,
#     305                     _single(0), self.dilation, self.groups)
# --> 306 return F.conv1d(input, weight, bias, self.stride,
#     307                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
train_loss = []
val_loss = []
train_loader = torch.utils.data.DataLoader(train_set, shuffle=False)
val_loader = torch.utils.data.DataLoader(val_set, shuffle=False)

for i in range(90):
    net = CNNLSTM()
    if torch.cuda.is_available():
        state = torch.load("ckpt/01112023_mse_batchsize_64_learningrate_0_epoch_%d" % i)
        net.load_state_dict(state)
        net.cuda()
    else:
        state = torch.load("ckpt/01112023_mse_batchsize_64_learningrate_0_epoch_%d" % i, map_location=torch.device('cpu'))


    train_loss.append(evaluate(net, train_loader, nn.MSELoss()))
    val_loss.append(evaluate(net, val_loader, nn.MSELoss()))

epochs = list(range(90))
plt.plot(epochs, train_loss)
plt.plot(epochs, val_loss)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\xueti\OneDrive - National University of Singapore\Courses\Y2S1-SEP\APS360\Project\training.ipynb Cell 18 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training.ipynb#X23sZmlsZQ%3D%3D?line=12'>13</a>         state = torch.load("ckpt/01112023_mse_batchsize_64_learningrate_0_epoch_%d" % i, map_location=torch.device('cpu'))
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training.ipynb#X23sZmlsZQ%3D%3D?line=15'>16</a>     train_loss.append(evaluate(net, train_loader, nn.MSELoss()))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training.ipynb#X23sZmlsZQ%3D%3D?line=16'>17</a>     val_loss.append(evaluate(net, val_loader, nn.MSELoss()))
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training.ipynb#X23sZmlsZQ%3D%3D?line=18'>19</a> epochs = list(range(90))
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training.ipynb#X23sZmlsZQ%3D%3D?line=19'>20</a> plt.plot(epochs, train_loss)
#
# c:\Users\xueti\OneDrive - National University of Singapore\Courses\Y2S1-SEP\APS360\Project\training.ipynb Cell 18 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training.ipynb#X23sZmlsZQ%3D%3D?line=9'>10</a>   inputs = inputs.cuda()
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training.ipynb#X23sZmlsZQ%3D%3D?line=10'>11</a>   labels = labels.cuda()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training.ipynb#X23sZmlsZQ%3D%3D?line=12'>13</a> outputs = net(inputs)
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training.ipynb#X23sZmlsZQ%3D%3D?line=13'>14</a> loss = criterion(outputs, labels)
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training.ipynb#X23sZmlsZQ%3D%3D?line=14'>15</a> total_loss += loss.item()
#
# File c:\Users\xueti\anaconda3\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\xueti\anaconda3\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# c:\Users\xueti\OneDrive - National University of Singapore\Courses\Y2S1-SEP\APS360\Project\training.ipynb Cell 18 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training.ipynb#X23sZmlsZQ%3D%3D?line=23'>24</a> def forward(self, x):
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training.ipynb#X23sZmlsZQ%3D%3D?line=24'>25</a>     x = F.relu(self.norm1(torch.cat((x, self.conv1(x)), dim=1)))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training.ipynb#X23sZmlsZQ%3D%3D?line=25'>26</a>     x = F.relu(self.norm2(torch.cat((x, self.conv2(x)), dim=1)))
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training.ipynb#X23sZmlsZQ%3D%3D?line=26'>27</a>     x = F.relu(self.norm3(torch.cat((x, self.conv3(x)), dim=1)))
#      <a href='vscode-notebook-cell:/c%3A/Users/xueti/OneDrive%20-%20National%20University%20of%20Singapore/Courses/Y2S1-SEP/APS360/Project/training.ipynb#X23sZmlsZQ%3D%3D?line=27'>28</a>     x = self.pool(x)
#
# File c:\Users\xueti\anaconda3\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\xueti\anaconda3\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\xueti\anaconda3\lib\site-packages\torch\nn\modules\batchnorm.py:151, in _BatchNorm.forward(self, input)
#     148 if self.training and self.track_running_stats:
#     149     # TODO: if statement only here to tell the jit to skip emitting this when it is None
#     150     if self.num_batches_tracked is not None:  # type: ignore[has-type]
# --> 151         self.num_batches_tracked.add_(1)  # type: ignore[has-type]
#     152         if self.momentum is None:  # use cumulative moving average
#     153             exponential_average_factor = 1.0 / float(self.num_batches_tracked)
#
# KeyboardInterrupt:

# %%
train_loss_tensor = torch.tensor(train_loss)
val_loss_tensor = torch.tensor(val_loss)

torch.save(train_loss_tensor, 'train_loss.pt')
torch.save(val_loss_tensor, 'val_loss.pt')

# %%
train_loss_tensor = torch.load('train_loss.pt')
val_loss_tensor = torch.load('val_loss.pt')

epochs = list(range(90))
plt.title("Train and Validation Loss")
plt.plot(epochs, train_loss_tensor, label='Training Loss')
plt.plot(epochs, val_loss_tensor, label = 'Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(loc='best')
plt.show()

# %%
net = CNNLSTM()
state = torch.load("ckpt/skip_connections/22112023/no_max_pool/skip_connection/22112023_mse_batchsize_64_learningrate_0_epoch_65")
net.load_state_dict(state)

net.cuda()

test_loader = DataLoader(test_set, batch_size=len(test_set), shuffle=False)
data, label = next(iter(test_loader))
data = data.float().cuda()
pred = net(data)

t = range(1000)
plt.title("PM2.5 concentration over 1000 days ")
plt.plot(t, label.transpose(0,1)[0], 'r', label="Label")
plt.plot(t, pred.cpu().detach().numpy().transpose(0,1)[:,0], 'b', label='Prediction')
plt.xlabel("Days")
plt.ylabel("PM2.5 Concentration")
plt.legend(loc='best')
plt.show()

# %%
print(pred.cpu()[:,0].shape)
print(label.transpose(0,1)[0].shape)

nn.MSELoss()(pred.cpu()[:,0], label.transpose(0,1)[0])
# Out:
# torch.Size([1000])
# torch.Size([1000])
# tensor(65.5570, dtype=torch.float64, grad_fn=<MseLossBackward0>)

# %% [markdown]
# # Making Video of Changes in Validation Loss

# %%
train_loss = []
val_loss = []

for i in range(90):
    net = CNNLSTM()
    if torch.cuda.is_available():
        state = torch.load("ckpt/cnnlstm/01112023_mse_batchsize_64_learningrate_0_epoch_%d" % i)
        net.load_state_dict(state)
        net.cuda()
    else:
        state = torch.load("ckpt/01112023_mse_batchsize_64_learningrate_0_epoch_%d" % i, map_location=torch.device('cpu'))
    
    val_loader = DataLoader(val_set, batch_size=len(val_set), shuffle=False)
    data, label = next(iter(val_loader))
    data = data.float().cuda()
    pred = net(data)

    t = range(len(val_set))
    plt.title("PM2.5 concentration over 1000 days ")
    plt.plot(t, label.transpose(0,1)[0], 'r', label="Label")
    plt.plot(t, pred.cpu().detach().numpy().transpose(0,1)[:,0], 'b', label='Prediction')
    plt.xlabel("Days")
    plt.ylabel("PM2.5 Concentration")
    plt.legend(loc='best')
    plt.savefig('Images/Validation/%d' % i)

    train_loader = DataLoader(train_set, batch_size=len(train_set), shuffle=False)
    data, label = next(iter(train_loader))
    data = data.float().cuda()
    pred = net(data)

    t = range(len(train_set))
    plt.title("PM2.5 concentration over 1000 days ")
    plt.plot(t, label.transpose(0,1)[0], 'r', label="Label")
    plt.plot(t, pred.cpu().detach().numpy().transpose(0,1)[:,0], 'b', label='Prediction')
    plt.xlabel("Days")
    plt.ylabel("PM2.5 Concentration")
    plt.legend(loc='best')
    plt.savefig('Images/Validation/%d' % i)
